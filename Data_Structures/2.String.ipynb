# %%
# ascii representation 
char="A"
ord(char)
# Out:
# 65

# %%
chr(97)
# Out:
# 'a'

# %%
# uniicode representation
"\u03A9" # omega
# Out:
# 'Ω'

# %%
#strings
string1 = "Piyush Aggarwal"
type(string1)
# Out:
# str

# %%
# concatenation
"Hello" + " world"
# Out:
# 'Hello world'

# %%
# indexing 
str=string1
str[0] #P
str[-1] #h
type(str[0])
# Out:
# str

# %%
str[0:3] # 3 is exckusive Piy
# Out:
# 'Piy'

# %%
str[0:] # from starting to end
# Out:
# 'Piyush Aggarwal'

# %%
str[0:-3] # only last 3 character
# str[-3:]
# str[:5]
# Out:
# 'Piyush Aggar'

# %%
str[0:5:2]#syntax>> [start:end:step]
# Out:
# 'Pys'

# %%
str[::-1]
# Out:
# 'lawraggA hsuyiP'

# %%
str[0]="a"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 str[0]="a"
#
# TypeError: 'str' object does not support item assignment

# %%
len(str)
# Out:
# 15

# %%
# modification 
s=str.replace("Aggarwal","Agg")

# %%
str
# Out:
# 'Piyush Aggarwal'

# %%
s="hello world"
s.upper()
# Out:
# 'HELLO WORLD'

# %%
s.lower()
s.title()
s.swapcase()
s.capitalize()
# Out:
# 'Hello world'

# %%
#string searching
sentence = "I am a student at pwskills"
"am" in sentence
sentence = "I am a student at pwskills"
search_word = "mat"
if search_word in sentence:
    print("The search word is present")
else:
    print("Not present")
# Out:
# Not present

# %%
#string comparison
str1 = "hello"
str2 = "hello"
str1 == str2
# Out:
# True

# %%
reg_username = ["pw", "PW", "pW"]
new_user = "PW1"
if new_user in reg_username:
    print("already in use")
else:
    print("username is available")
# Out:
# username is available

# %%
#STRING ORDERING
name = ["Piyush", "Sanjay", "Bijay"]
sorted(name)
# Out:
# ['Bijay', 'Piyush', 'Sanjay']

# %%
# common string opertation 
s="    Piyush    "
s.strip()
# Out:
# 'Piyush'

# %%
s="Piyush, Aggarwal"
name=s.split(",")

# %%
# escape chaaractere
table = "Name\tAge\tGrade\npiyush\t21\tA\nBijay\t22\tA+"
print(table)
# Out:
# Name	Age	Grade
# piyush	21	A
# Bijay	22	A+

# %%
#\' single quote escape
str1 = 'I can\'t believe its friday'
print(str1)
# Out:
# I can't believe its friday

# %%
#carriage return \r >> moves the cursor to the beginning of line
print("Hello, I am \rAjay, I am going to delhi")
# Out:
# Ajay, I am going to delhi

# %%
# f strings 
name = "Bijay"
greetings = f"hello {name}, how are you?"
print(greetings)
# Out:
# hello Bijay, how are you?

# %%
#string formatting
name = "PW Skills"
greeting = "Hello %s, wish you a wonderful day"%name
print(greeting)
# Out:
# Hello PW Skills, wish you a wonderful day

# %%
#.format
template = "Hello, {} welcome to {}"
message = template.format("Ajay", "Data Science")
print(message)
# Out:
# Hello, Ajay welcome to Data Science

# %%
str1 = "pwskills"
str1.startswith("pws")

str1.startswith("aws")
# Out:
# False

# %%
a = "Abs"
a.isalnum()
